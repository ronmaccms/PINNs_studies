# %%
import numpy as np

# %%
data = np.load('anti_derivative.npy', allow_pickle = True).item()

# %%
data
# Out:
# {'a_train': array([[ 1.3559822 ,  1.4176242 ,  1.4781287 , ..., -1.4910872 ,
#          -1.3590919 , -1.224976  ],
#         [ 1.4915037 ,  1.4131662 ,  1.3294691 , ...,  1.4372327 ,
#           1.4389585 ,  1.4306684 ],
#         [-1.8004574 , -1.7120639 , -1.6141785 , ...,  0.76864517,
#           0.74957645,  0.72174066],
#         ...,
#         [ 0.9035444 ,  0.91332996,  0.9119296 , ...,  0.55388564,
#           0.55498815,  0.55285007],
#         [-2.5551202 , -2.5589294 , -2.555358  , ..., -2.2073684 ,
#          -2.1458158 , -2.0854585 ],
#         [-0.81431913, -0.8121347 , -0.809583  , ...,  2.1515079 ,
#           2.0657365 ,  1.9784439 ]], dtype=float32),
#  'x_train': array([[0.7425288 ],
#         [0.23492004],
#         [0.19262293],
#         ...,
#         [0.2387453 ],
#         [0.39193752],
#         [0.70940167]], dtype=float32),
#  'u_train': array([[ 0.49643627],
#         [ 0.08384103],
#         [-0.10456767],
#         ...,
#         [ 0.08367757],
# ...

# %%
data_test = np.load('validator_3.npz', allow_pickle = True)

# %%
data_test
# Out:
# NpzFile 'validator_3.npz' with keys: arr_0

# %%
data_use = data_test['arr_0']

# %%
data_use
# Out:
# array({'a': array([[-0.8300956 , -0.8535989 , -0.87096816, ...,  0.03688757,
#          0.03448195,  0.03363571],
#        [-0.8300956 , -0.8535989 , -0.87096816, ...,  0.03688757,
#          0.03448195,  0.03363571],
#        [-0.8300956 , -0.8535989 , -0.87096816, ...,  0.03688757,
#          0.03448195,  0.03363571],
#        ...,
#        [-0.8300956 , -0.8535989 , -0.87096816, ...,  0.03688757,
#          0.03448195,  0.03363571],
#        [-0.8300956 , -0.8535989 , -0.87096816, ...,  0.03688757,
#          0.03448195,  0.03363571],
#        [-0.8300956 , -0.8535989 , -0.87096816, ...,  0.03688757,
#          0.03448195,  0.03363571]], dtype=float32), 'x': array([[0.        ],
#        [0.01010101],
#        [0.02020202],
#        [0.03030303],
#        [0.04040404],
#        [0.05050505],
#        [0.06060606],
#        [0.07070707],
#        [0.08080808],
#        [0.09090909],
#        [0.1010101 ],
#        [0.11111111],
#        [0.12121212],
#        [0.13131313],
# ...

# %%
dictionary = data_use.item()

# %%
dictionary
# Out:
# {'a': array([[-0.8300956 , -0.8535989 , -0.87096816, ...,  0.03688757,
#           0.03448195,  0.03363571],
#         [-0.8300956 , -0.8535989 , -0.87096816, ...,  0.03688757,
#           0.03448195,  0.03363571],
#         [-0.8300956 , -0.8535989 , -0.87096816, ...,  0.03688757,
#           0.03448195,  0.03363571],
#         ...,
#         [-0.8300956 , -0.8535989 , -0.87096816, ...,  0.03688757,
#           0.03448195,  0.03363571],
#         [-0.8300956 , -0.8535989 , -0.87096816, ...,  0.03688757,
#           0.03448195,  0.03363571],
#         [-0.8300956 , -0.8535989 , -0.87096816, ...,  0.03688757,
#           0.03448195,  0.03363571]], dtype=float32),
#  'x': array([[0.        ],
#         [0.01010101],
#         [0.02020202],
#         [0.03030303],
#         [0.04040404],
#         [0.05050505],
#         [0.06060606],
#         [0.07070707],
#         [0.08080808],
#         [0.09090909],
#         [0.1010101 ],
#         [0.11111111],
#         [0.12121212],
# ...

# %%
true_u = dictionary ['true_u']
pred_u = dictionary ['pred_u']
a = dictionary ['a']
x = dictionary ['x']

# %%
true_u.shape
# Out:
# (100, 1)

# %%
pred_u.shape
# Out:
# (100, 1)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(a[0], label='a')
plt.plot(pred_u, label='pred_u')
plt.plot(true_u, label='true_u')
plt.legend()
