# %% [markdown]
# # Exercise 2b: Topic modeling on a custom pdf document.
# It is time to put your skills to test! We want to load a pdf document with python, explode it to different pages and perform topic modeling.

# %% [markdown]
# ## Libraries

# %%
# %%capture
# !pip install pypdf2
# !pip install bertopic datasets accelerate bitsandbytes xformers adjustText

# %%
from sentence_transformers.models.Asym import import_from_string
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from umap import UMAP
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import requests
from io import BytesIO
from PyPDF2 import PdfReader
from tqdm import tqdm

# %% [markdown]
# The following cells help you download a pdf from a link, parse it into pages and create a dataset. You can alternatively upload a pdf and specify its path directly.

# %%
def get_pdf_as_memory_stream(url):
    response = requests.get(url)
    response.raise_for_status()  # Raise an error for HTTP errors

    # Convert the response content into a BytesIO stream
    return BytesIO(response.content)

# %% [markdown]
# For this part of the exercise, we can use Specifications for Structural Steel buildings from American Institute of Steel Construction (AISC) which is publically available.

# %%
aisc_360_path = "https://www.aisc.org/globalassets/aisc/publications/standards/a360-16w-rev-june-2019.pdf"
aisc_pdf_file = get_pdf_as_memory_stream(aisc_360_path)

# %%
reader = PdfReader(aisc_pdf_file)
# number of pages
print(f"Number of pages: {len(reader.pages)}")
# Out:
# Number of pages: 680

# %% [markdown]
# Let's test how an extracted pdf page looks like:

# %%
page = reader.pages[400]
print(page.extract_text())
# Out:
# Comm. F10.] SINGLE ANGLES 16.1-343
# Specification for Structural Steel Buildings, July 7, 2016
# AMERICAN INSTITUTE OF STEEL CONSTRUCTIONstrength, Mn=1.5M y, will occur when the theoretical buckling moment, M cr, reaches
# or exceeds 7.7M y. Myis the moment at first yield in Equations F10-2 and F10-3, the
# same as the Myin Equation F10-1. These equations are modifications of those devel-
# oped from the results of Australian research on single angles in flexure and on ananalytical model consisting of two rectangular elements of length equal to the actualangle leg width minus one-half the thickness (AISC, 1975; Leigh and Lay, 1978,1984; Madugula and Kennedy, 1985). When bending is applied about one leg of a laterally unrestrained single angle, theangle will deflect laterally as well as in the bending direction. Its behavior can beevaluated by resolving the load and/or moments into principal axis components anddetermining the sum of these principal axis flexural effects. Subsection (i) of SectionF10.2(2) is provided to simplify and expedite the calculations for this common situ-ation with equal-leg angles. For such unrestrained bending of an equal-leg angle, theresulting maximum normal stress at the angle tip (in the direction of bending) will beapproximately 25% greater than the calculated stress using the geometric axis sec-tion modulus. The value of M
# crgiven by Equations F10-5a and F10-5b and the
# evaluation of M yusing 0.80 of the geometric axis section modulus reflect bending
# about the inclined axis shown in Figure C-F10.2. Dumonteil (2009) compares theresults using the geometric axis approach with that of the principal axis approach forlateral-torsional buckling.The deflection calculated using the geometric axis moment of inertia has to beincreased 82% to approximate the total deflection. Deflection has two components:a vertical component (in the direction of applied load) of 1.56 times the calculatedvalue and a horizontal component of 0.94 times the calculated value. The resultanttotal deflection is in the general direction of the minor principal axis bending of the
# Fig. C-F10.2. Deflection for geometric axis bending of laterally unrestrained equal-leg angles.9 AISC_PART 16_Comm E-H (307-369)_15Ed._July 2016  2016-12-14  10:39 AM  Page 343    (Black plate)

# %% [markdown]
# Now, we will collect all extracted pages in a single list. For a real data science project, there is benefits in cleaning the text data and removing irrelevant sections.  For example, one might remove table of contents.

# %%
dataset = []
for i in tqdm(range(len(reader.pages))):
  page_i = reader.pages[i]
  dataset.append(page_i.extract_text())
# Out:
# 100%|██████████| 680/680 [00:44<00:00, 15.31it/s]

# %%
dataset[251]
# Out:
# '16.1-194 IMPROVED DESIGN FOR PONDING [App. 2.2.\nSpecification for Structural Steel Buildings, July 7, 2016\nAMERICAN INSTITUTE OF STEEL CONSTRUCTION\nFig. A-2.1. Limiting flexibility coefficient for the primary systems.7 AISC_PART 16_A_Spec. L-App2-App8 (192-252)_15th Ed._2016  2016-11-14  3:53 PM  Page 194    (Black plate)'

# %% [markdown]
# ## Students are expected to complete the rest of this excercise based on the previous example

# %%
# Prepare embeddings
sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = sentence_model.encode(dataset, show_progress_bar=True)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Batches:   0%|          | 0/22 [00:00<?, ?it/s]

# %%
topic_model = BERTopic().fit(dataset, embeddings)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                 Name  \
# 0      -1    117                     -1_the_of_for_in
# 1       0     66       0_the_steel_composite_concrete
# 2       1     47                 1_analysis_the_of_in
# 3       2     45                2_buckling_the_for_of
# 4       3     42                    3_load_of_the_and
# 5       4     41                  4_branch_the_hss_of
# 6       5     39         5_inspection_and_for_welding
# 7       6     34    6_fire_temperature_the_structural
# 8       7     33        7_bracing_the_brace_stiffness
# 9       8     32                  8_weld_the_welds_to
# 10      9     28                  9_bolts_the_to_bolt
# 11     10     27   10_web_the_stiffeners_concentrated
# 12     11     23                  11_pp_ol_journal_no
# 13     12     19  12_flange_ishaped_compact_symmetric
# 14     13     17              13_the_of_connection_in
# 15     14     16   14_general_requirements_design_and
# 16     15     15     15_fatigue_stress_a31_parameters
# 17     16     14                  16_metal_weld_or_at
# 18     17     13          17_the_story_length_columns
# 19     18     12                    18_kips_app_mm_of
#
#                                        Representation  \
# 0   [the, of, for, in, and, to, is, strength, with...
# 1   [the, steel, composite, concrete, of, to, stre...
# 2   [analysis, the, of, in, to, and, secondorder, ...
# 3   [buckling, the, for, of, in, angles, is, and, ...
# 4   [load, of, the, and, structural, design, speci...
# 5   [branch, the, hss, of, chord, for, in, connect...
# 6   [inspection, and, for, welding, the, of, stand...
# 7   [fire, temperature, the, structural, and, of, ...
# 8   [bracing, the, brace, stiffness, to, of, point...
# 9   [weld, the, welds, to, of, metal, in, fillet, ...
# 10  [bolts, the, to, bolt, of, and, in, holes, sli...
# 11  [web, the, stiffeners, concentrated, forces, o...
# 12  [pp, ol, journal, no, and, engineering, of, st...
# 13  [flange, ishaped, compact, symmetric, the, mem...
# 14  [the, of, connection, in, to, or, and, member,...
# 15  [general, requirements, design, and, members, ...
# 16  [fatigue, stress, a31, parameters, design, ran...
# 17  [metal, weld, or, at, stress, base, mm, fatigu...
# 18  [the, story, length, columns, effective, in, o...
# 19  [kips, app, mm, of, in, strength, the, area, i...
#
#                                   Representative_Docs
# 0   [CHAPTER H\nDESIGN OF MEMBERS FOR COMBINED \nF...
# 1   [Sect. I8.] STEEL ANCHORS 16.1-109\nSpecificat...
# 2   [Comm. 1.3.] DESIGN BY INELASTIC ANALYSIS 16.1...
# 3   [Comm. F10.] SINGLE ANGLES 16.1-341\nSpecifica...
# 4   [Comm. B3.] DESIGN BASIS 16.1-269\nSpecificati...
# 5   [16.1-152 CONCENTRATED FORCES ON HSS [Sect. K2...
# 6   [Comm. N5.] MINIMUM REQUIREMENTS FOR INSPECTIO...
# 7   [16.1-222\nSpecification for Structural Steel ...
# 8   [16.1-238 GENERAL PROVISIONS [App. 6.1.\nSpeci...
# 9   [Sect. J1.] GENERAL PROVISIONS 16.1-115\nSpeci...
# 10  [16.1-126 BOLTS AND THREADED PARTS [Sect. J3.\...
# 11  [Sect. J10.] FLANGES AND WEBS WITH CONCENTRATE...
# 12  [REFERENCES 16.1-597\nSpecification for Struct...
# 13  [Sect. F3.] DOUBLY SYMMETRIC I-SHAPED MEMBERS ...
# 14  [                                             ...
# 15  [16.1-xxiv TABLE OF CONTENTS\nSpecification fo...
# 16  [16.1-196\nSpecification for Structural Steel ...
# 17  [16.1-212 FATIGUE DESIGN PARAMETERS [Table A-3...
# 18  [16.1-246 EFFFECTIVE LENGTH METHOD [App. 7.2.\...
# 19  [16.1 -xxviii                                 ...

# %%
topic_model.get_document_info(dataset)
# Out:
#                                               Document  Topic  \
# 0    ANSI/AISC 360-16\nAn American National Standar...      3
# 1                                                          -1
# 2    ANSI/AISC 360-16\nAn American National Standar...      3
# 3                                                  ...      3
# 4    16.1-iii\nSpecification for Structural Steel B...      3
# ..                                                 ...    ...
# 675  16.1-618 REFERENCES\nSpecification for Structu...      1
# 676  METRIC CONVERSION FACTORS 16.1-619\nSpecificat...      6
# 677  16.1-620\nSpecification for Structural Steel B...      3
# 678                                                        -1
# 679  A360-16Smarter. Stronger. Steel.\nAmerican Ins...      3
#
#                                   Name  \
# 0                    3_load_of_the_and
# 1                     -1_the_of_for_in
# 2                    3_load_of_the_and
# 3                    3_load_of_the_and
# 4                    3_load_of_the_and
# ..                                 ...
# 675               1_analysis_the_of_in
# 676  6_fire_temperature_the_structural
# 677                  3_load_of_the_and
# 678                   -1_the_of_for_in
# 679                  3_load_of_the_and
#
#                                         Representation  \
# 0    [load, of, the, and, structural, design, speci...
# 1    [the, of, for, in, and, to, is, strength, with...
# 2    [load, of, the, and, structural, design, speci...
# 3    [load, of, the, and, structural, design, speci...
# 4    [load, of, the, and, structural, design, speci...
# ..                                                 ...
# 675  [analysis, the, of, in, to, and, secondorder, ...
# 676  [fire, temperature, the, structural, and, of, ...
# 677  [load, of, the, and, structural, design, speci...
# 678  [the, of, for, in, and, to, is, strength, with...
# 679  [load, of, the, and, structural, design, speci...
#
#                                    Representative_Docs  \
# 0    [Comm. B3.] DESIGN BASIS 16.1-269\nSpecificati...
# 1    [CHAPTER H\nDESIGN OF MEMBERS FOR COMBINED \nF...
# 2    [Comm. B3.] DESIGN BASIS 16.1-269\nSpecificati...
# 3    [Comm. B3.] DESIGN BASIS 16.1-269\nSpecificati...
# 4    [Comm. B3.] DESIGN BASIS 16.1-269\nSpecificati...
# ..                                                 ...
# 675  [Comm. 1.3.] DESIGN BY INELASTIC ANALYSIS 16.1...
# 676  [16.1-222\nSpecification for Structural Steel ...
# 677  [Comm. B3.] DESIGN BASIS 16.1-269\nSpecificati...
# 678  [CHAPTER H\nDESIGN OF MEMBERS FOR COMBINED \nF...
# 679  [Comm. B3.] DESIGN BASIS 16.1-269\nSpecificati...
#
#                                            Top_n_words  Probability  \
# 0    load - of - the - and - structural - design - ...     1.000000
# 1    the - of - for - in - and - to - is - strength...     0.000000
# 2    load - of - the - and - structural - design - ...     1.000000
# 3    load - of - the - and - structural - design - ...     1.000000
# 4    load - of - the - and - structural - design - ...     1.000000
# ..                                                 ...          ...
# 675  analysis - the - of - in - to - and - secondor...     0.467821
# 676  fire - temperature - the - structural - and - ...     0.502825
# 677  load - of - the - and - structural - design - ...     1.000000
# 678  the - of - for - in - and - to - is - strength...     0.000000
# 679  load - of - the - and - structural - design - ...     1.000000
#
#      Representative_document
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ..                       ...
# 675                    False
# 676                    False
# 677                    False
# 678                    False
# 679                    False
#
# [680 rows x 8 columns]

# %%
topic_model.get_topic(5)
# Out:
# [('inspection', 0.03962346679380569),
#  ('and', 0.038534683108101174),
#  ('for', 0.03377247337270443),
#  ('welding', 0.028827702483794498),
#  ('the', 0.02859114972818962),
#  ('of', 0.02789951465582364),
#  ('standard', 0.02727157317595078),
#  ('quality', 0.0261745300659607),
#  ('be', 0.025560014179039536),
#  ('steel', 0.024060275322371764)]

# %%
topic_model.visualize_barchart(top_n_topics=50,n_words=5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e5fbdf5c-07ba-4947-9e58-e762e8d4707b" class="plotly-graph-div" style="height:1250px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5fbdf5c-07ba-4947-9e58-e762e8d4707b")) {                    Plotly.newPlot(                        "e5fbdf5c-07ba-4947-9e58-e762e8d4707b",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.03374338416748881,0.03650423379963442,0.039255913847608986,0.042010315843174884,0.04327191167660487],"y":["of  ","concrete  ","composite  ","steel  ","the  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.029240964361958614,0.034062618050963875,0.03586507989974464,0.03964935609200285,0.047622500882274384],"y":["to  ","in  ","of  ","the  ","analysis  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.027959363200354435,0.029171461417056486,0.03140044435764024,0.03909590963601789,0.04264572595482745],"y":["in  ","of  ","for  ","the  ","buckling  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.030033486288482115,0.030686505946734787,0.032434975824709396,0.03560110345737784,0.0362674681548106],"y":["structural  ","and  ","the  ","of  ","load  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.03499383528310016,0.036231711148457996,0.03871309471714139,0.03943808252430795,0.05074719194004669],"y":["chord  ","of  ","hss  ","the  ","branch  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.02859114972818962,0.028827702483794498,0.03377247337270443,0.038534683108101174,0.03962346679380569],"y":["the  ","welding  ","for  ","and  ","inspection  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.03006517720899889,0.0301031716144452,0.0317006301677936,0.032161182008029934,0.0570249853168906],"y":["and  ","structural  ","the  ","temperature  ","fire  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.029282733918877646,0.034296959143269204,0.04252780101388698,0.04739571311426209,0.08246683174709585],"y":["to  ","stiffness  ","brace  ","the  ","bracing  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.0357963236092893,0.03736476938809735,0.04392488566003497,0.04448265468450481,0.06134181947266494],"y":["of  ","to  ","welds  ","the  ","weld  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.028753414224793675,0.03052791528308125,0.03149390387930952,0.0360997811029466,0.044546776962720774],"y":["of  ","bolt  ","to  ","the  ","bolts  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.028186158359724683,0.029369681991531116,0.030399384489268308,0.03896736363136364,0.056939797487942916],"y":["forces  ","concentrated  ","stiffeners  ","the  ","web  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.05125606887776278,0.05576303575739413,0.05656473481104047,0.06025589185315269,0.0664552109889674],"y":["and  ","no  ","journal  ","ol  ","pp  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.03438894333649957,0.03540781933704049,0.03901460950040311,0.04381680064788735,0.061347263347168],"y":["the  ","symmetric  ","compact  ","ishaped  ","flange  "],"type":"bar","xaxis":"x13","yaxis":"y13"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.030664916257833182,0.030900890477220663,0.03457818935597275,0.036825666740179286,0.041290907197014455],"y":["to  ","in  ","connection  ...

# %%
fig= topic_model.visualize_topics()
fig.write_html("topics_LLM.html")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2fb88688-6df8-4e66-ad8e-23c0510f8948" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fb88688-6df8-4e66-ad8e-23c0510f8948")) {                    Plotly.newPlot(                        "2fb88688-6df8-4e66-ad8e-23c0510f8948",                        [{"customdata":[[0,"the | steel | composite | concrete | of",66],[1,"analysis | the | of | in | to",47],[2,"buckling | the | for | of | in",45],[3,"load | of | the | and | structural",42],[4,"branch | the | hss | of | chord",41],[5,"inspection | and | for | welding | the",39],[6,"fire | temperature | the | structural | and",34],[7,"bracing | the | brace | stiffness | to",33],[8,"weld | the | welds | to | of",32],[9,"bolts | the | to | bolt | of",28],[10,"web | the | stiffeners | concentrated | forces",27],[11,"pp | ol | journal | no | and",23],[12,"flange | ishaped | compact | symmetric | the",19],[13,"the | of | connection | in | to",17],[14,"general | requirements | design | and | members",16],[15,"fatigue | stress | a31 | parameters | design",15],[16,"metal | weld | or | at | stress",14],[17,"the | story | length | columns | effective",13],[18,"kips | app | mm | of | in",12]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[66,47,45,42,41,39,34,33,32,28,27,23,19,17,16,15,14,13,12],"sizemode":"area","sizeref":0.04125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-0.6551623940467834,14.286460876464844,13.862122535705566,14.196450233459473,-1.2888453006744385,14.51625919342041,13.830045700073242,14.37897777557373,-10.359856605529785,-1.0679124593734741,5.166120529174805,-0.5617050528526306,4.9519243240356445,-0.7724732160568237,-7.104945182800293,-10.73593807220459,-10.579133033752441,14.143174171447754,-6.92441987991333],"xaxis":"x","y":[15.600872993469238,-0.8548807501792908,-0.14296060800552368,-1.4852381944656372,16.163497924804688,-1.5948928594589233,-1.7257777452468872,-0.11843882501125336,5.4241790771484375,16.56186866760254,6.71040153503418,15.82050895690918,6.496326923370361,16.152793884277344,-5.534905910491943,5.0484466552734375,5.205229759216309,-0.3277167081832886,-5.354398727416992],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar ...

# %%
topic_model.visualize_heatmap(height=1000,width=1000)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9c754f2d-2489-4684-a058-056eaa7018ba" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c754f2d-2489-4684-a058-056eaa7018ba")) {                    Plotly.newPlot(                        "9c754f2d-2489-4684-a058-056eaa7018ba",                        [{"coloraxis":"coloraxis","name":"0","x":["0_the_steel_composite","1_analysis_the_of","2_buckling_the_for","3_load_of_the","4_branch_the_hss","5_inspection_and_for","6_fire_temperature_the","7_bracing_the_brace","8_weld_the_welds","9_bolts_the_to","10_web_the_stiffeners","11_pp_ol_journal","12_flange_ishaped_compact","13_the_of_connection","14_general_requirements_des...","15_fatigue_stress_a31","16_metal_weld_or","17_the_story_length","18_kips_app_mm"],"y":["0_the_steel_composite","1_analysis_the_of","2_buckling_the_for","3_load_of_the","4_branch_the_hss","5_inspection_and_for","6_fire_temperature_the","7_bracing_the_brace","8_weld_the_welds","9_bolts_the_to","10_web_the_stiffeners","11_pp_ol_journal","12_flange_ishaped_compact","13_the_of_connection","14_general_requirements_des...","15_fatigue_stress_a31","16_metal_weld_or","17_the_story_length","18_kips_app_mm"],"z":[[0.9999998807907104,0.8236576318740845,0.7873729467391968,0.8143312931060791,0.730627179145813,0.6489510536193848,0.725156307220459,0.8062811493873596,0.6712354421615601,0.7530556917190552,0.7904064655303955,0.8528445959091187,0.6751159429550171,0.850212037563324,0.702893853187561,0.7085217237472534,0.7139269709587097,0.7850751876831055,0.7550854682922363],[0.8236576318740845,1.0000003576278687,0.8293666839599609,0.8483666181564331,0.731096625328064,0.6380853056907654,0.7512713074684143,0.837671160697937,0.6402310132980347,0.7241255044937134,0.767771303653717,0.8078219890594482,0.6905537843704224,0.8164732456207275,0.7343696355819702,0.7154494524002075,0.6970067024230957,0.8831213116645813,0.7761023640632629],[0.7873729467391968,0.8293666839599609,0.9999998211860657,0.7213630676269531,0.7553776502609253,0.5842214822769165,0.678783655166626,0.8411556482315063,0.6778014898300171,0.6899290084838867,0.8163648843765259,0.745978057384491,0.8551250696182251,0.7705870866775513,0.6640094518661499,0.6571617126464844,0.6994185447692871,0.8551273345947266,0.7365635633468628],[0.8143312931060791,0.8483666181564331,0.7213630676269531,0.9999999403953552,0.7238953113555908,0.787760317325592,0.7892862558364868,0.7453242540359497,0.661634087562561,0.747785747051239,0.7078012228012085,0.7830499410629272,0.6073393821716309,0.8338243961334229,0.8105870485305786,0.795161783695221,0.728668212890625,0.7592930793762207,0.8345292210578918],[0.730627179145813,0.731096625328064,0.7553776502609253,0.7238953113555908,1.0000001192092896,0.6671324968338013,0.6613765954971313,0.709028959274292,0.7905158996582031,0.7683751583099365,0.7595542073249817,0.7648058533668518,0.6837178468704224,0.8630380034446716,0.6971372365951538,0.6630463600158691,0.7348684668540955,0.754057765007019,0.7700353860855103],[0.6489510536193848,0.6380853056907654,0.5842214822769165,0.787760317325592,0.6671324968338013,1.0000001192092896,0.6404478549957275,0.5870952606201172,0.7450205087661743,0.7067248821258545,0.5999845266342163,0.6552457213401794,0.5104572772979736,0.7000865340232849,0.6887249946594238,0.6619604825973511,0.7315583229064941,0.5931563377380371,0.7129416465759277],[0.725156307220459,0.7512713074684143,0.678783655166626,0.7892862558364868,0.6613765954971313,0.6404478549957275,1.0000001192092896,0.6721534729003906,0.6201531291007996,0.6513029932975769,0.6500566005706787,0.7624534368515015,0.578818678855896,0.7320183515548706,0.6830790042877197,0.6423122882843018,0.6426235437393188,0.6874507665634155,0.6977027654647827],[0.8062811493873596,0.837671160 ...

# %%
# Marteen suggests reducing dimensionality of embeddings, this step is optional but much faster to perform iteratively:
reduced_embeddings = UMAP(n_neighbors=10, n_components=2, min_dist=0.0, metric='cosine').fit_transform(embeddings)
fig = topic_model.visualize_documents(dataset, reduced_embeddings=reduced_embeddings,height=1200,width=1800)
fig.write_html("document_view.html")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f3781282-0a91-4386-9103-7b1c1006834a" class="plotly-graph-div" style="height:1200px; width:1800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3781282-0a91-4386-9103-7b1c1006834a")) {                    Plotly.newPlot(                        "f3781282-0a91-4386-9103-7b1c1006834a",                        [{"hoverinfo":"text","hovertext":["Sect. I1.] GENERAL PROVISIONS 16.1-89\nSpecification for Structural Steel Buildings, July 7, 2016\nAMERICAN INSTITUTE OF STEEL CONSTRUCTIONTABLE I1.1a\nLimiting Width-to-Thickness Ratios for \nCompression Steel Elements in Composite \nMembers Subject to Axial Compression\nfor Use with Section I2.2\nWidth-to- \u03bbp \u03bbr\nDescription of Thickness Compact\u002f Noncompact\u002f Maximum\nElement Ratio Noncompact Slender Permitted\nWalls of Rectangular HSS and Box Sections of Uniform ThicknessRound HSS22 6 .E\nFy30 0 .E\nFy\n01 5 .E\nFy01 9 .E\nFy03 1 .E\nFy50 0 .E\nFy\nTABLE I1.1b\nLimiting Width-to-Thickness Ratios for \nCompression Steel Elements in Composite \nMembers Subject to Flexure \nfor Use with Section I3.4\nWidth-to- \u03bbp \u03bbr\nDescription of Thickness Compact\u002f Noncompact\u002f Maximum\nElement Ratio Noncompact Slender Permitted\nFlanges of Rectangular HSS and Box Sections of Uniform ThicknessWebs of Rectangular HSS and Box Sections of Uniform ThicknessRound HSS22 6 .E\nFy30 0 .E\nFy\n30 0 .E\nFy57 0 .E\nFy57 0 .E\nFy\n00 9 .E\nFy03 1 .E\nFy03 1 .E\nFy50 0 .E\nFyb\u002ft\nb\u002ft\nh\u002ft\nD\u002ftD\u002f t3 AISC_PART 16_A_Spec. G-I (70-112)_15th Ed._2016  2016-11-14  2:22 PM  Page 89    (Black plate)","For major-axis bending, an equation approximating the average yield strength ofwide-flange shapes when P \u22651.5P\nyis given as\n(C-H1-4)\nWhen P \u003c0.15P y, Mpcmay be taken as Mp.\nThe curves in Figure C-H1.2 show the exact and approximate yield interaction curvesfor wide-flange shapes bent about the y-axis, and the exact curves for the solid rec-\ntangular and round shapes. It is evident that the lower-bound AISC interaction curvesare very conservative for these shapes.The idea of portraying the strength of stub beam-columns was extended to actualbeam-columns with actual lengths by normalizing the required flexural strength, M\nu,\nof the beam by the nominal strength of a beam without axial force, Mn, and the\nrequired axial strength, Pu, by the nominal strength of a column without bending\nmoment, P n. This rearrangement results in a translation and rotation of the original\nstub-column interaction curve, as seen in Figure C-H1.3.The normalized equations corresponding to the beam-column with length effectsincluded are shown as Equation C-H1-5:\n(C-H1-5a)M\nM=P\nP pc\npy1.18 1\u2013 1\u239b\u239d\u239c\u239e\u23a0\u239f\u2264\nP\nPMMPP\nununu\nn\n+= \u22658910 2     for .16.1-358 DOUBLY AND SINGLY SYMMETRIC MEMBERS [Comm. H1.\nSpecification for Structural Steel Buildings , July 7, 2016\nAMERICAN INSTITUTE OF STEEL CONSTRUCTIONFig. C-H1.1. Stub-column interaction curves: plastic moment versus axial \nforce for wide-flange shapes, major-axis flexure\n[W8\u00d731, Fy=50 ksi (345 MPa)].9 AISC_PART 16_Comm E-H (307-369)_15Ed._July 2016  2016-11-09  8:33 AM  Page 358    (Black plate)","The required flexural strength of indeterminate beams composed of compact sec-tions, as defined in Section B4.1, carrying gravity loads only, and satisfying theunbraced length requirements of Section F13.5, is permitted to be taken as nine-tenths of the negative moments at the points of support, produced by the gravityloading and determined by an elastic analysis satisfying the requirements of ChapterC, provided that the maximum positive moment is increased by one-tenth of the aver-age negative moment determined by an elastic analy ...
